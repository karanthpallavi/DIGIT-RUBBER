# %%
import pandas as pd

# %%
df = pd.read_excel('./CQs_USs_Excel.xlsx', header=[0,1,2], index_col=[1,0], na_values='')
# df = df.droplevel(1)
df = df.loc[:,~df.columns.str.match("Unnamed")]
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[77], line 3
#       1 df = pd.read_excel('./CQs_USs_Excel.xlsx', header=[0,1,2], index_col=[1,0], na_values='')
#       2 # df = df.droplevel(1)
# ----> 3 df = df.loc[:,~df.columns.str.match("Unnamed")]
#       4 df.head(10)
#
# File ~/miniconda3/envs/digitrubber/lib/python3.11/site-packages/pandas/core/accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File ~/miniconda3/envs/digitrubber/lib/python3.11/site-packages/pandas/core/strings/accessor.py:180, in StringMethods.__init__(self, data)
#     177 def __init__(self, data) -> None:
#     178     from pandas.core.arrays.string_ import StringDtype
# --> 180     self._inferred_dtype = self._validate(data)
#     181     self._is_categorical = is_categorical_dtype(data.dtype)
#     182     self._is_string = isinstance(data.dtype, StringDtype)
#
# File ~/miniconda3/envs/digitrubber/lib/python3.11/site-packages/pandas/core/strings/accessor.py:220, in StringMethods._validate(data)
#     198 """
#     199 Auxiliary function for StringMethods, infers and checks dtype of data.
#     200
#    (...)
#     217 dtype : inferred dtype of data
#     218 """
#     219 if isinstance(data, ABCMultiIndex):
# --> 220     raise AttributeError(
#     221         "Can only use .str accessor with Index, not MultiIndex"
#     222     )
#     224 # see _libs/lib.pyx for list of inferred types
#     225 allowed_types = ["string", "empty", "bytes", "mixed", "mixed-integer"]
#
# AttributeError: Can only use .str accessor with Index, not MultiIndex

# %%
df.columns
# Out:
# MultiIndex([('Description (Competency Questions and User Stories)', ...),
#             (                                      'Ind. priority', ...),
#             (                                    'Global priority', ...),
#             (                                       'Work package', ...),
#             (                          'Project partners involved', ...),
#             (                             'Workflow Specification', ...),
#             (                             'Workflow Specification', ...),
#             (                             'Workflow Specification', ...),
#             (                             'Workflow Specification', ...),
#             (                             'Workflow Specification', ...),
#             (                             'Workflow Specification', ...),
#             (                             'Workflow Specification', ...),
#             (                             'Workflow Specification', ...),
#             (                             'Workflow Specification', ...),
#             (                             'Workflow Specification', ...),
#             (                             'Workflow Specification', ...),
#             (                             'Workflow Specification', ...),
#             (                             'Workflow Specification', ...),
#             (                             'Workflow Specification', ...),
#             (                             'Workflow Specification', ...),
#             (                        'Concepts and Ontology Terms', ...),
#             (                           'Technical Implementation', ...),
#             (                           'Technical Implementation', ...),
#             (                               'Related User Stories', ...)],
#            names=['ID (CQ & US)', None, None])

# %%
#df = df.drop(columns=[0])
df.to_excel('output.xlsx')

# %%
df.columns.tolist()
# Out:
# [('Description (Competency Questions and User Stories)',
#   'Unnamed: 2_level_1',
#   'Unnamed: 2_level_2'),
#  ('Ind. priority', 'Unnamed: 3_level_1', 'Unnamed: 3_level_2'),
#  ('Global priority', 'Unnamed: 4_level_1', 'Unnamed: 4_level_2'),
#  ('Work package', 'Unnamed: 5_level_1', 'Unnamed: 5_level_2'),
#  ('Project partners involved', 'Unnamed: 6_level_1', 'Unnamed: 6_level_2'),
#  ('Workflow Specification',
#   'Required INPUT',
#   'Data type and description (what is the "input" data about?)'),
#  ('Workflow Specification',
#   'Required INPUT',
#   'From where do you get the data/material using which technology?'),
#  ('Workflow Specification',
#   'Required INPUT',
#   'Who (project partner) provides the data/material?'),
#  ('Workflow Specification',
#   'Required INPUT',
#   'Do you need the data/material in a specific structure/format/preparation?'),
#  ('Workflow Specification',
#   'Required INPUT',
#   'How often do you need the data/material (data/material exchange frequency)?'),
#  ('Workflow Specification',
#   'Workflow (processing, from INPUT -> OUTPUT)',
#   'Workflow name'),
#  ('Workflow Specification',
#   'Workflow (processing, from INPUT -> OUTPUT)',
#   'Workflow description'),
#  ('Workflow Specification',
#   'Workflow (processing, from INPUT -> OUTPUT)',
#   'What is the objective or goal of the workflow?'),
#  ('Workflow Specification',
#   'Resulting OUTPUT',
#   'Type of data/material and description (what is the "output" data/material about?)'),
#  ('Workflow Specification',
#   'Resulting OUTPUT',
#   'Who (project partner) will use the data/material?'),
#  ('Workflow Specification',
#   'Resulting OUTPUT',
#   'Do you provide the data/material in a specific structure/format?'),
#  ('Workflow Specification',
#   'Resulting OUTPUT',
#   'How often do you provide the data/material (data/material exchange frequency)?'),
#  ('Workflow Specification',
#   'Resulting OUTPUT',
#   'Where does the data/material go next? Does it need to be stored in a database? Or how do you make it available to others?'),
#  ('Workflow Specification',
#   'Resulting OUTPUT',
#   'Does all the generated data/material need to be stored or only a summary?'),
#  ('Workflow Specification',
#   'Resulting OUTPUT',
#   'Should the data/material be stored permantly or only for a limited time? If only for a limited time, for how long?'),
#  ('Concepts and Ontology Terms',
#   'Unnamed: 22_level_1',
#   'Which concepts/terms are relevant for this CQ, which are needed for documenting and sharing data? '),
#  ('Technical Implementation',
#   'Unnamed: 23_level_1',
#   'Which type of database is based suited for the task (i.e., answering the CQ)?'),
#  ('Technical Implementation',
#   'Unnamed: 24_level_1',
#   'Query for the CQ (in an specific format, e.g sql, sparql)'),
#  ('Related User Stories', 'Unnamed: 25_level_1', 'Unnamed: 25_level_2')]

# %%
# split dataframe

df_CQ = df.iloc[0:141]
df_US = df.iloc[145:]

# %%
df_CQ.tail()
# Out:
# ID (CQ & US) Description (Competency Questions and User Stories)
#                                               Unnamed: 2_level_1
#                                               Unnamed: 2_level_2
# 53 IMR:01_CQ  What is the accepted value range (min/max) of ...   \
# 54 IMR:02_CQ  Can we achieve shape X with values Y1…..Yn in ...
# 55 IMR:03_CQ  How does the shape of the extrudate change dep...
# 56 IMR:04_CQ  What is the tolerance of properties Z1 … Zn fo...
# 57 IMR:05_CQ  Which file type should be used for further app...
#
# ID (CQ & US)      Ind. priority    Global priority       Work package
#              Unnamed: 3_level_1 Unnamed: 4_level_1 Unnamed: 5_level_1
#              Unnamed: 3_level_2 Unnamed: 4_level_2 Unnamed: 5_level_2
# 53 IMR:01_CQ                  8                NaN          3.2 + 3.3  \
# 54 IMR:02_CQ                  9                NaN          3.2 + 3.3
# 55 IMR:03_CQ                  8                NaN          3.2 + 3.3
# 56 IMR:04_CQ                NaN                NaN                NaN
# 57 IMR:05_CQ                  8                NaN          3.2 + 3.3
#
# ID (CQ & US) Project partners involved
#                     Unnamed: 6_level_1
#                     Unnamed: 6_level_2
# 53 IMR:01_CQ                 DIK, IAPG  \
# 54 IMR:02_CQ                 DIK, IAPG
# 55 IMR:03_CQ                 DIK, IAPG
# 56 IMR:04_CQ                       NaN
# 57 IMR:05_CQ                 DIK, IAPG
#
# ID (CQ & US)                                      Workflow Specification
#                                                           Required INPUT
#              Data type and description (what is the "input" data about?)
# 53 IMR:01_CQ                  nominal diameter of the extrudate           \
# 54 IMR:02_CQ                     nominal shape of the extrudate
# 55 IMR:03_CQ        nominal output temperature of the extrudate
# 56 IMR:04_CQ                                                NaN
# 57 IMR:05_CQ            file type of triangulation measurements
#
# ID (CQ & US)
#
#              From where do you get the data/material using which technology?
# 53 IMR:01_CQ  DIK informs IMR of the nominal diameter for th...               \
# 54 IMR:02_CQ  DIK informs IMR of the nominal shape for the r...
# 55 IMR:03_CQ  DIK informs IMR of the nominal temperature of ...
# 56 IMR:04_CQ                                                NaN
# 57 IMR:05_CQ  IAPG, (DIK) and IMR reconcile a file type form...
#
# ID (CQ & US)
#
#              Who (project partner) provides the data/material?
# 53 IMR:01_CQ                                         DIK, IAPG  \
# 54 IMR:02_CQ                                         DIK, IAPG
# 55 IMR:03_CQ                                         DIK, IAPG
# 56 IMR:04_CQ                                               NaN
# 57 IMR:05_CQ                                         DIK, IAPG
#
# ID (CQ & US)
#
#              Do you need the data/material in a specific structure/format/preparation?
# 53 IMR:01_CQ                                                NaN                         \
# 54 IMR:02_CQ                                                NaN
# 55 IMR:03_CQ                                                NaN
# 56 IMR:04_CQ                                                NaN
# 57 IMR:05_CQ                                                NaN
#
# ID (CQ & US)
#
#              How often do you need the data/material (data/material exchange frequency)?
# 53 IMR:01_CQ                                                NaN                           \
# 54 IMR:02_CQ                                                NaN
# 55 IMR:03_CQ                                                NaN
# 56 IMR:04_CQ                                                NaN
# 57 IMR:05_CQ                                                NaN
#
# ID (CQ & US)  ...
#               ...                                  Resulting OUTPUT
#               ... Who (project partner) will use the data/material?
# 53 IMR:01_CQ  ...                                               DIK  \
# 54 IMR:02_CQ  ...                                               DIK
# 55 IMR:03_CQ  ...                                               DIK
# 56 IMR:04_CQ  ...                                               NaN
# 57 IMR:05_CQ  ...                                               DIK
#
# ID (CQ & US)
#
#              Do you provide the data/material in a specific structure/format?
# 53 IMR:01_CQ                                                NaN                \
# 54 IMR:02_CQ                                                NaN
# 55 IMR:03_CQ                                                NaN
# 56 IMR:04_CQ                                                NaN
# 57 IMR:05_CQ                                                NaN
#
# ID (CQ & US)
#
#              How often do you provide the data/material (data/material exchange frequency)?
# 53 IMR:01_CQ                                                NaN                              \
# 54 IMR:02_CQ                                                NaN
# 55 IMR:03_CQ                                                NaN
# 56 IMR:04_CQ                                                NaN
# 57 IMR:05_CQ                                                NaN
#
# ID (CQ & US)
#
#              Where does the data/material go next? Does it need to be stored in a database? Or how do you make it available to others?
# 53 IMR:01_CQ  IMR informs DIK of the actual diameter for the...                                                                         \
# 54 IMR:02_CQ  IMR informs DIK of the actual shape for the ex...
# 55 IMR:03_CQ  IMR informs DIK of the actual temperature and ...
# 56 IMR:04_CQ                                                NaN
# 57 IMR:05_CQ  IMR informs DIK of the actual temperature and ...
#
# ID (CQ & US)
#
#              Does all the generated data/material need to be stored or only a summary?
# 53 IMR:01_CQ                                                NaN                         \
# 54 IMR:02_CQ                                                NaN
# 55 IMR:03_CQ                                                NaN
# 56 IMR:04_CQ                                                NaN
# 57 IMR:05_CQ                                                NaN
#
# ID (CQ & US)
#
#              Should the data/material be stored permantly or only for a limited time? If only for a limited time, for how long?
# 53 IMR:01_CQ                                                NaN                                                                  \
# 54 IMR:02_CQ                                                NaN
# 55 IMR:03_CQ                                                NaN
# 56 IMR:04_CQ                                                NaN
# 57 IMR:05_CQ                                                NaN
#
# ID (CQ & US)                                                                        Concepts and Ontology Terms
#                                                                                             Unnamed: 22_level_1
#              Which concepts/terms are relevant for this CQ, which are needed for documenting and sharing data?
# 53 IMR:01_CQ                                                NaN                                                  \
# 54 IMR:02_CQ                                                NaN
# 55 IMR:03_CQ                                                NaN
# 56 IMR:04_CQ                                                NaN
# 57 IMR:05_CQ                                                NaN
#
# ID (CQ & US)                                                      Technical Implementation
#                                                                        Unnamed: 23_level_1
#              Which type of database is based suited for the task (i.e., answering the CQ)?
# 53 IMR:01_CQ                                                NaN                             \
# 54 IMR:02_CQ                                                NaN
# 55 IMR:03_CQ                                                NaN
# 56 IMR:04_CQ                                                NaN
# 57 IMR:05_CQ                                                NaN
#
# ID (CQ & US)
#                                                    Unnamed: 24_level_1
#              Query for the CQ (in an specific format, e.g sql, sparql)
# 53 IMR:01_CQ                                                NaN         \
# 54 IMR:02_CQ                                                NaN
# 55 IMR:03_CQ                                                NaN
# 56 IMR:04_CQ                                                NaN
# 57 IMR:05_CQ                                                NaN
#
# ID (CQ & US) Related User Stories
#               Unnamed: 25_level_1
#               Unnamed: 25_level_2
# 53 IMR:01_CQ                IMR-U
# 54 IMR:02_CQ                IMR-U
# 55 IMR:03_CQ                IMR-U
# 56 IMR:04_CQ                IMR-U
# 57 IMR:05_CQ                IMR-U
#
# [5 rows x 24 columns]

# %%
# set column names
df_US.droplevel(level=0)


# df_US.columns = df_US.iloc[0]
df_US.head()
# Out:
# ID (CQ & US)     Description (Competency Questions and User Stories)
#                                                   Unnamed: 2_level_1
#                                                   Unnamed: 2_level_2
# 57 User Story ID                                  User Stories LIST   \
# 1  HSH_US_1.      As a top-level manager in the context of rubbe...
# 2  HSH_US_2.      As a manager in the context of rubber processi...
# 3  HSH_US_3.      As a manager in the context of rubber processi...
# 4  HSH_US_4.      As a manager in the context of quality control...
#
# ID (CQ & US)          Ind. priority    Global priority       Work package
#                  Unnamed: 3_level_1 Unnamed: 4_level_1 Unnamed: 5_level_1
#                  Unnamed: 3_level_2 Unnamed: 4_level_2 Unnamed: 5_level_2
# 57 User Story ID                NaN                NaN                NaN  \
# 1  HSH_US_1.                    NaN                NaN                NaN
# 2  HSH_US_2.                    NaN                NaN                NaN
# 3  HSH_US_3.                    NaN                NaN                NaN
# 4  HSH_US_4.                    NaN                NaN                NaN
#
# ID (CQ & US)     Project partners involved
#                         Unnamed: 6_level_1
#                         Unnamed: 6_level_2
# 57 User Story ID                       NaN  \
# 1  HSH_US_1.                           NaN
# 2  HSH_US_2.                           NaN
# 3  HSH_US_3.                           NaN
# 4  HSH_US_4.                           NaN
#
# ID (CQ & US)                                          Workflow Specification
#                                                               Required INPUT
#                  Data type and description (what is the "input" data about?)
# 57 User Story ID                                                NaN           \
# 1  HSH_US_1.                                                    NaN
# 2  HSH_US_2.                                                    NaN
# 3  HSH_US_3.                                                    NaN
# 4  HSH_US_4.                                                    NaN
#
# ID (CQ & US)
#
#                  From where do you get the data/material using which technology?
# 57 User Story ID                                                NaN               \
# 1  HSH_US_1.                                                    NaN
# 2  HSH_US_2.                                                    NaN
# 3  HSH_US_3.                                                    NaN
# 4  HSH_US_4.                                                    NaN
#
# ID (CQ & US)
#
#                  Who (project partner) provides the data/material?
# 57 User Story ID                                               NaN  \
# 1  HSH_US_1.                                                   NaN
# 2  HSH_US_2.                                                   NaN
# 3  HSH_US_3.                                                   NaN
# 4  HSH_US_4.                                                   NaN
#
# ID (CQ & US)
#
#                  Do you need the data/material in a specific structure/format/preparation?
# 57 User Story ID                                                NaN                         \
# 1  HSH_US_1.                                                    NaN
# 2  HSH_US_2.                                                    NaN
# 3  HSH_US_3.                                                    NaN
# 4  HSH_US_4.                                                    NaN
#
# ID (CQ & US)
#
#                  How often do you need the data/material (data/material exchange frequency)?
# 57 User Story ID                                                NaN                           \
# 1  HSH_US_1.                                                    NaN
# 2  HSH_US_2.                                                    NaN
# 3  HSH_US_3.                                                    NaN
# 4  HSH_US_4.                                                    NaN
#
# ID (CQ & US)      ...
#                   ...                                  Resulting OUTPUT
#                   ... Who (project partner) will use the data/material?
# 57 User Story ID  ...                                               NaN  \
# 1  HSH_US_1.      ...                                               NaN
# 2  HSH_US_2.      ...                                               NaN
# 3  HSH_US_3.      ...                                               NaN
# 4  HSH_US_4.      ...                                               NaN
#
# ID (CQ & US)
#
#                  Do you provide the data/material in a specific structure/format?
# 57 User Story ID                                                NaN                \
# 1  HSH_US_1.                                                    NaN
# 2  HSH_US_2.                                                    NaN
# 3  HSH_US_3.                                                    NaN
# 4  HSH_US_4.                                                    NaN
#
# ID (CQ & US)
#
#                  How often do you provide the data/material (data/material exchange frequency)?
# 57 User Story ID                                                NaN                              \
# 1  HSH_US_1.                                                    NaN
# 2  HSH_US_2.                                                    NaN
# 3  HSH_US_3.                                                    NaN
# 4  HSH_US_4.                                                    NaN
#
# ID (CQ & US)
#
#                  Where does the data/material go next? Does it need to be stored in a database? Or how do you make it available to others?
# 57 User Story ID                                                NaN                                                                         \
# 1  HSH_US_1.                                                    NaN
# 2  HSH_US_2.                                                    NaN
# 3  HSH_US_3.                                                    NaN
# 4  HSH_US_4.                                                    NaN
#
# ID (CQ & US)
#
#                  Does all the generated data/material need to be stored or only a summary?
# 57 User Story ID                                                NaN                         \
# 1  HSH_US_1.                                                    NaN
# 2  HSH_US_2.                                                    NaN
# 3  HSH_US_3.                                                    NaN
# 4  HSH_US_4.                                                    NaN
#
# ID (CQ & US)
#
#                  Should the data/material be stored permantly or only for a limited time? If only for a limited time, for how long?
# 57 User Story ID                                                NaN                                                                  \
# 1  HSH_US_1.                                                    NaN
# 2  HSH_US_2.                                                    NaN
# 3  HSH_US_3.                                                    NaN
# 4  HSH_US_4.                                                    NaN
#
# ID (CQ & US)                                                                            Concepts and Ontology Terms
#                                                                                                 Unnamed: 22_level_1
#                  Which concepts/terms are relevant for this CQ, which are needed for documenting and sharing data?
# 57 User Story ID                                                NaN                                                  \
# 1  HSH_US_1.                                                    NaN
# 2  HSH_US_2.                                                    NaN
# 3  HSH_US_3.                                                    NaN
# 4  HSH_US_4.                                                    NaN
#
# ID (CQ & US)                                                          Technical Implementation
#                                                                            Unnamed: 23_level_1
#                  Which type of database is based suited for the task (i.e., answering the CQ)?
# 57 User Story ID                                                NaN                             \
# 1  HSH_US_1.                                                    NaN
# 2  HSH_US_2.                                                    NaN
# 3  HSH_US_3.                                                    NaN
# 4  HSH_US_4.                                                    NaN
#
# ID (CQ & US)
#                                                        Unnamed: 24_level_1
#                  Query for the CQ (in an specific format, e.g sql, sparql)
# 57 User Story ID                                                NaN         \
# 1  HSH_US_1.                                                    NaN
# 2  HSH_US_2.                                                    NaN
# 3  HSH_US_3.                                                    NaN
# 4  HSH_US_4.                                                    NaN
#
# ID (CQ & US)     Related User Stories
#                   Unnamed: 25_level_1
#                   Unnamed: 25_level_2
# 57 User Story ID                  NaN
# 1  HSH_US_1.                      NaN
# 2  HSH_US_2.                      NaN
# 3  HSH_US_3.                      NaN
# 4  HSH_US_4.                      NaN
#
# [5 rows x 24 columns]

# %%
# clean df_US data and extract userstories from each partner in different csv file

df_US = df_US.dropna(axis=1).iloc[1:]

p_abbrv = ['DIK', 'HSH', 'IFNANO', 'IMR', 'ITA', 'JADE']

for i in p_abbrv:
    df_US[df_US['User Story ID'].str.match(i, case=False)].to_csv('./userstories/'+i+'_US.csv', index=False, encoding='utf-8')

# %%
df_CQ.columns.to_list()
# Out:
# [('ID (CQ & US)', 'Unnamed: 1_level_1', 'Unnamed: 1_level_2'),
#  ('Description (Competency Questions and User Stories)',
#   'Unnamed: 2_level_1',
#   'Unnamed: 2_level_2'),
#  ('Ind. priority', 'Unnamed: 3_level_1', 'Unnamed: 3_level_2'),
#  ('Global priority', 'Unnamed: 4_level_1', 'Unnamed: 4_level_2'),
#  ('Work package', 'Unnamed: 5_level_1', 'Unnamed: 5_level_2'),
#  ('Project partners involved', 'Unnamed: 6_level_1', 'Unnamed: 6_level_2'),
#  ('Workflow Specification',
#   'Required INPUT',
#   'Data type and description (what is the "input" data about?)'),
#  ('Workflow Specification',
#   'Required INPUT',
#   'From where do you get the data/material using which technology?'),
#  ('Workflow Specification',
#   'Required INPUT',
#   'Who (project partner) provides the data/material?'),
#  ('Workflow Specification',
#   'Required INPUT',
#   'Do you need the data/material in a specific structure/format/preparation?'),
#  ('Workflow Specification',
#   'Required INPUT',
#   'How often do you need the data/material (data/material exchange frequency)?'),
#  ('Workflow Specification',
#   'Workflow (processing, from INPUT -> OUTPUT)',
#   'Workflow name'),
#  ('Workflow Specification',
#   'Workflow (processing, from INPUT -> OUTPUT)',
#   'Workflow description'),
#  ('Workflow Specification',
#   'Workflow (processing, from INPUT -> OUTPUT)',
#   'What is the objective or goal of the workflow?'),
#  ('Workflow Specification',
#   'Resulting OUTPUT',
#   'Type of data/material and description (what is the "output" data/material about?)'),
#  ('Workflow Specification',
#   'Resulting OUTPUT',
#   'Who (project partner) will use the data/material?'),
#  ('Workflow Specification',
#   'Resulting OUTPUT',
#   'Do you provide the data/material in a specific structure/format?'),
#  ('Workflow Specification',
#   'Resulting OUTPUT',
#   'How often do you provide the data/material (data/material exchange frequency)?'),
#  ('Workflow Specification',
#   'Resulting OUTPUT',
#   'Where does the data/material go next? Does it need to be stored in a database? Or how do you make it available to others?'),
#  ('Workflow Specification',
#   'Resulting OUTPUT',
#   'Does all the generated data/material need to be stored or only a summary?'),
#  ('Workflow Specification',
#   'Resulting OUTPUT',
#   'Should the data/material be stored permantly or only for a limited time? If only for a limited time, for how long?'),
#  ('Concepts and Ontology Terms',
#   'Unnamed: 22_level_1',
#   'Which concepts/terms are relevant for this CQ, which are needed for documenting and sharing data? '),
#  ('Technical Implementation',
#   'Unnamed: 23_level_1',
#   'Which type of database is based suited for the task (i.e., answering the CQ)?'),
#  ('Technical Implementation',
#   'Unnamed: 24_level_1',
#   'Query for the CQ (in an specific format, e.g sql, sparql)'),
#  ('Related User Stories', 'Unnamed: 25_level_1', 'Unnamed: 25_level_2')]

# %%
# clean df_US data and extract userstories from each partner in different csv file


p_abbrv = ['DIK', 'HSH', 'IFNANO', 'IMR', 'ITA', 'JADE']

# df_CQ[('ID (CQ & US)', 'Unnamed: 1_level_1', 'Unnamed: 1_level_2')] = df_CQ[('ID (CQ & US)', 'Unnamed: 1_level_1', 'Unnamed: 1_level_2')].ffill()

for i in p_abbrv:
    df_CQ[df_CQ[('ID (CQ & US)', 'Unnamed: 1_level_1', 'Unnamed: 1_level_2')].str.match(i, case=False)].to_csv('./competency_questions/'+i+'_CQ.csv', index=False, encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 9
#       6 # df_CQ[('ID (CQ & US)', 'Unnamed: 1_level_1', 'Unnamed: 1_level_2')] = df_CQ[('ID (CQ & US)', 'Unnamed: 1_level_1', 'Unnamed: 1_level_2')].ffill()
#       8 for i in p_abbrv:
# ----> 9     df_CQ[df_CQ[('ID (CQ & US)', 'Unnamed: 1_level_1', 'Unnamed: 1_level_2')].str.match(i, case=False)].to_csv('./competency_questions/'+i+'_CQ.csv', index=False, encoding='utf-8')
#
# File ~/miniconda3/envs/digitrubber/lib/python3.11/site-packages/pandas/core/frame.py:3750, in DataFrame.__getitem__(self, key)
#    3747     return self.where(key)
#    3749 # Do we have a (boolean) 1d indexer?
# -> 3750 if com.is_bool_indexer(key):
#    3751     return self._getitem_bool_array(key)
#    3753 # We are left with two options: a single key, and a collection of keys,
#    3754 # We interpret tuples as collections only for non-MultiIndex
#
# File ~/miniconda3/envs/digitrubber/lib/python3.11/site-packages/pandas/core/common.py:134, in is_bool_indexer(key)
#     130     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     131     if lib.infer_dtype(key_array) == "boolean" and isna(key_array).any():
#     132         # Don't raise on e.g. ["A", "B", np.nan], see
#     133         #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 134         raise ValueError(na_msg)
#     135     return False
#     136 return True
#
# ValueError: Cannot mask with non-boolean array containing NA / NaN values

# %%
df_CQ.head(20)
# Out:
# count       ID (CQ & US) Description (Competency Questions and User Stories)
#       Unnamed: 1_level_1                                  Unnamed: 2_level_1
#       Unnamed: 1_level_2                                  Unnamed: 2_level_2
# 1           IFNANO:01_CQ             What is the LIBS-Spectrum of a sample?   \
# 2           IFNANO:02_CQ  How homogeneous is the zinc concentration dist...
# 3           IFNANO:03_CQ  What is the distribution quality of zinc in th...
# 4           IFNANO:04_CQ  What is the Raman-Spectrum of a raw rubber sam...
# 5           IFNANO:05_CQ  What is the ATR-FTIR-Spectrum of a raw rubber ...
# 6           IFNANO:06_CQ  What is the correlation between Raman spectral...
# 6                    NaN                                                NaN
# 7           IFNANO:07_CQ  What is the correlation between ATR-FTIR spect...
# 8           IFNANO:08_CQ  How can the raw samples be statistically discr...
# 8                    NaN                                                NaN
# 9           IFNANO:09_CQ  What is a photometric measurement of a raw rub...
# 10          IFNANO:10_CQ  What is the correlation between photometric da...
# 10                   NaN                                                NaN
# 11          IFNANO:11_CQ  How can the raw samples be statistically discr...
# 11                   NaN                                                NaN
# 12             HsH:01_CQ  What is the unit cost of producing product X u...
# 12                   NaN                                                NaN
# 12                   NaN                                                NaN
# 12                   NaN                                                NaN
# 12                   NaN                                                NaN
#
# count      Ind. priority    Global priority       Work package
#       Unnamed: 3_level_1 Unnamed: 4_level_1 Unnamed: 5_level_1
#       Unnamed: 3_level_2 Unnamed: 4_level_2 Unnamed: 5_level_2
# 1                     10                NaN                4.1  \
# 2                     10                NaN                4.1
# 3                     10                NaN                4.1
# 4                     10                NaN              1.2.2
# 5                     10                NaN              1.2.2
# 6                     10                NaN              1.2.3
# 6                    NaN                NaN                NaN
# 7                     10                NaN              1.2.3
# 8                     10                NaN              1.2.3
# 8                    NaN                NaN                NaN
# 9                     10                NaN              1.2.4
# 10                    10                NaN              1.2.4
# 10                   NaN                NaN                NaN
# 11                    10                NaN              1.2.4
# 11                   NaN                NaN                NaN
# 12                     9                NaN              7.1.2
# 12                   NaN                NaN                NaN
# 12                   NaN                NaN                NaN
# 12                   NaN                NaN                NaN
# 12                   NaN                NaN                NaN
#
# count Project partners involved
#              Unnamed: 6_level_1
#              Unnamed: 6_level_2
# 1                    IFNANO/DIK  \
# 2                    IFNANO/DIK
# 3                    IFNANO/DIK
# 4                    IFNANO/DIK
# 5                    IFNANO/DIK
# 6                    IFNANO/DIK
# 6                           NaN
# 7                    IFNANO/DIK
# 8                    IFNANO/DIK
# 8                           NaN
# 9               IFNANO/DIK/JADE
# 10                   IFNANO/DIK
# 10                          NaN
# 11                   IFNANO/DIK
# 11                          NaN
# 12                          DIK
# 12                          NaN
# 12                          NaN
# 12                          NaN
# 12                          NaN
#
# count                                      Workflow Specification
#                                                    Required INPUT
#       Data type and description (what is the "input" data about?)
# 1                           identification of the sample           \
# 2                           identification of the sample
# 3         velocity of the conveyor belt behind extruder.
# 4                     Property profiles of raw materials
# 5                     Property profiles of raw materials
# 6      Physicochemical material properties of raw rub...
# 6                                Raman spectral database
# 7      Physicochemical material properties of raw rub...
# 8      Physicochemical material properties of raw rub...
# 8                             ATR-FTIR spectral database
# 9                     Property profiles of raw materials
# 10     Physicochemical material properties of raw rub...
# 10                               Raman spectral database
# 11     Physicochemical material properties of raw rub...
# 11                            photometric image database
# 12     Human resources costs per hour and job role (l...
# 12        maintenance costs per day and machine (static)
# 12           raw material storage costs per day (static)
# 12       finished product storage costs per day (static)
# 12              energy costs per hour and machine (live)
#
# count
#
#       From where do you get the data/material using which technology?
# 1                           from dik?, see next colum!.                \
# 2                                                    NaN
# 3      conveyor belt behind the extruder, using LIBS ...
# 4                                     Raw rubber sample?
# 5                                                    NaN
# 6                                             DIK, email
# 6                                             DIK, email
# 7                                             DIK, email
# 8                                             DIK, email
# 8                                             DIK, email
# 9                                             DIK, email
# 10                                            DIK, email
# 10                                            DIK, email
# 11                                            DIK, email
# 11                                            DIK, email
# 12     data collection based on secondary data source...
# 12                                                   NaN
# 12                                                   NaN
# 12                                                   NaN
# 12                                                   NaN
#
# count
#
#       Who (project partner) provides the data/material?
# 1                                            DIK/WP:4.1  \
# 2                                            DIK/WP:4.1
# 3                                          DIK/IAPG/IMR
# 4                                                   DIK
# 5                                                   DIK
# 6                                            DIK/IFNANO
# 6                                            DIK/IFNANO
# 7                                            DIK/IFNANO
# 8                                            DIK/IFNANO
# 8                                            DIK/IFNANO
# 9                                                   DIK
# 10                                           DIK/IFNANO
# 10                                           DIK/IFNANO
# 11                                           DIK/IFNANO
# 11                                           DIK/IFNANO
# 12                                              HsH/DIK
# 12                                                  NaN
# 12                                                  NaN
# 12                                                  NaN
# 12                                                  NaN
#
# count
#
#       Do you need the data/material in a specific structure/format/preparation?
# 1                                                    NaN                         \
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 10                                                   NaN
# 11                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 12                                                   NaN
# 12                                                   NaN
# 12                                                   NaN
# 12                                                   NaN
#
# count  ...
#        ...                                  Resulting OUTPUT
#        ... Who (project partner) will use the data/material?
# 1      ...                             IFNANO, DIK, Database  \
# 2      ...                             IFNANO, DIK, Database
# 3      ...                                        IFNANO/DIK
# 4      ...                                        IFNANO/DIK
# 5      ...                                        IFNANO/DIK
# 6      ...                                        IFNANO/DIK
# 6      ...                                               NaN
# 7      ...                                        DIK/IFNANO
# 8      ...                                        DIK/IFNANO
# 8      ...                                               NaN
# 9      ...                                        DIK/IFNANO
# 10     ...                                        DIK/IFNANO
# 10     ...                                               NaN
# 11     ...                                        DIK/IFNANO
# 11     ...                                               NaN
# 12     ...                                               HSH
# 12     ...                                               NaN
# 12     ...                                               NaN
# 12     ...                                               NaN
# 12     ...                                               NaN
#
# count
#
#       Do you provide the data/material in a specific structure/format?
# 1                                                    NaN                \
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 10                                                   NaN
# 11                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 12                                                   NaN
# 12                                                   NaN
# 12                                                   NaN
# 12                                                   NaN
#
# count
#
#       How often do you provide the data/material (data/material exchange frequency)?
# 1                                                    NaN                              \
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 10                                                   NaN
# 11                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 12                                                   NaN
# 12                                                   NaN
# 12                                                   NaN
# 12                                                   NaN
#
# count
#
#       Where does the data/material go next? Does it need to be stored in a database? Or how do you make it available to others?
# 1                                               database                                                                         \
# 2      LIBS-Spectra are obtained and analyzed. The re...
# 3      These are either submitted to the database and...
# 4      Receiving the raw samples from DIK, preparing ...
# 5      Receiving the raw samples from DIK, preparing ...
# 6      smooth the spectra, correct baselines and norm...
# 6                                                    NaN
# 7      smooth the spectra, correct baselines and norm...
# 8      MIR spectra are reduced to main components or ...
# 8                                                    NaN
# 9      Receiving the raw samples from DIK, preparing ...
# 10     Fourier analysis, histograms and other derived...
# 10                                                   NaN
# 11     Data from fourier analysis, histograms and oth...
# 11                                                   NaN
# 12     determination of products for analysis – deter...
# 12                                                   NaN
# 12                                                   NaN
# 12                                                   NaN
# 12                                                   NaN
#
# count
#
#       Does all the generated data/material need to be stored or only a summary?
# 1                                                    NaN                         \
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 10                                                   NaN
# 11                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 12                                                   NaN
# 12                                                   NaN
# 12                                                   NaN
# 12                                                   NaN
#
# count
#
#       Should the data/material be stored permantly or only for a limited time? If only for a limited time, for how long?
# 1                                                    NaN                                                                  \
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 10                                                   NaN
# 11                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 12                                                   NaN
# 12                                                   NaN
# 12                                                   NaN
# 12                                                   NaN
#
# count                                                                        Concepts and Ontology Terms
#                                                                                      Unnamed: 22_level_1
#       Which concepts/terms are relevant for this CQ, which are needed for documenting and sharing data?
# 1                                                    NaN                                                  \
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 10                                                   NaN
# 11                                                   NaN
# 11                                                   NaN
# 12     unit cost of production, average costs, cost p...
# 12                                                   NaN
# 12                                                   NaN
# 12                                                   NaN
# 12                                                   NaN
#
# count                                                      Technical Implementation
#                                                                 Unnamed: 23_level_1
#       Which type of database is based suited for the task (i.e., answering the CQ)?
# 1                                                    NaN                             \
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 10                                                   NaN
# 11                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 12                                                   NaN
# 12                                                   NaN
# 12                                                   NaN
# 12                                                   NaN
#
# count
#                                             Unnamed: 24_level_1
#       Query for the CQ (in an specific format, e.g sql, sparql)
# 1                                                    NaN         \
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 10                                                   NaN
# 11                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 12                                                   NaN
# 12                                                   NaN
# 12                                                   NaN
# 12                                                   NaN
#
# count                       Related User Stories
#                              Unnamed: 25_level_1
#                              Unnamed: 25_level_2
# 1       IFNANO_US_14, IFNANO_US_15, IFNANO_US_16
# 2       IFNANO_US_14, IFNANO_US_15, IFNANO_US_16
# 3       IFNANO_US_14, IFNANO_US_15, IFNANO_US_16
# 4              IFNANO_US_1-5 and IFNANO_US_11-13
# 5              [IFNANO_US_1-5 and IFNANO_US_7-10
# 6      [IFNANO_US_14, IFNANO_US_15, IFNANO_US_16
# 6                                            NaN
# 7                                            NaN
# 8                                            NaN
# 8                                            NaN
# 9                                            NaN
# 10                                           NaN
# 10                                           NaN
# 11                                           NaN
# 11                                           NaN
# 12        HSH_US_1, HSH_US_6, HSH_US_7, HSH_US_8
# 12                                           NaN
# 12                                           NaN
# 12                                           NaN
# 12                                           NaN
#
# [20 rows x 25 columns]
